# %% [markdown]
# # Assignment 2 - B

# %% [markdown]
# ### importing and installing libraries

# %%
# !pip install pandas
# !pip install numpy
# !pip install statistics
# !pip install matplotlib
# !pip install seaborn
# !pip install sklearn
# !pip install category_encoders
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement math (from versions: none)
# ERROR: No matching distribution found for math
# ...
#   Using cached statistics-1.0.3.5.tar.gz (8.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for statistics: filename=statistics-1.0.3.5-py3-none-any.whl size=7452 sha256=efff0c74abd0fd9e9f2115aad5a00e713baa1b0afefa2d7a99a1534f147e587d
#   Stored in directory: c:\users\dsitepu\appdata\local\pip\cache\wheels\26\3c\70\9467407f3aa90862061eadcd286627b23a8bab6789b667776f
# Successfully built statistics
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=77f6ef9b4a6e478894230e54cc4c7777771328e9f31dafdea3aa4b5d394ec7a7
# ...

# %%
import pandas as pd
import numpy as np
import math as math
import statistics as stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import category_encoders as ce

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.2
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asgiref                            3.5.2
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# ...

# %% [markdown]
# # Assignment Problem

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
df = pd.read_csv('Dataset/voice_record_data.csv')

# %%
df
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %%
df.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %%
metadata = open("Dataset/metadata.txt", "r")
for line in metadata:
    print (line)
metadata.close()
# Out:
# The following acoustic properties of each voice are measured:
#
#
#
# meanfreq: mean frequency (in kHz)
#
# sd: standard deviation of frequency
#
# median: median frequency (in kHz)
#
# Q25: first quantile (in kHz)
#
# Q75: third quantile (in kHz)
#
# IQR: interquantile range (in kHz)
#
# skew: skewness (see note in specprop description)
#
# kurt: kurtosis (see note in specprop description)
#
# sp.ent: spectral entropy
#
# sfm: spectral flatness
#
# mode: mode frequency
#
# centroid: frequency centroid (see specprop)
#
# meanfun: average of fundamental frequency measured across acoustic signal
#
# minfun: minimum fundamental frequency measured across acoustic signal
#
# maxfun: maximum fundamental frequency measured across acoustic signal
#
# meandom: average of dominant frequency measured across acoustic signal
#
# mindom: minimum of dominant frequency measured across acoustic signal
#
# maxdom: maximum of dominant frequency measured across acoustic signal
#
# ...

# %%
df['label']
# Out:
# 0         male
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 3163    female
# 3164    female
# 3165    female
# 3166    female
# 3167    female
# Name: label, Length: 3168, dtype: object

# %%
#activate the onehotencoder
encoder = ce.OneHotEncoder()
df_encoded = encoder.fit_transform(df).head()
df_encoded
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...   meanfun    minfun    maxfun  \
# 0   274.402905  0.893369  0.491918  ...  0.084279  0.015702  0.275862
# 1   634.613855  0.892193  0.513724  ...  0.107937  0.015826  0.250000
# 2  1024.927705  0.846389  0.478905  ...  0.098706  0.015656  0.271186
# 3     4.177296  0.963322  0.727232  ...  0.088965  0.017798  0.250000
# 4     4.333713  0.971955  0.783568  ...  0.106398  0.016931  0.266667
#
#     meandom    mindom    maxdom   dfrange   modindx  label_1  label_2
# ...

# %%
df.chang

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('Dataset/insurance_claim.csv')
print(df)
# Out:
#       age  Gender     bmi  dependent smoker      charges
# 0      19  female  27.900          0    yes  16884.92400
# 1      18    male  33.770          1     no   1725.55230
# 2      28    male  33.000          3     no   4449.46200
# 3      33    male  22.705          0     no  21984.47061
# 4      32    male  28.880          0     no   3866.85520
# ...   ...     ...     ...        ...    ...          ...
# 1333   50    male  30.970          3     no  10600.54830
# 1334   18  female  31.920          0     no   2205.98080
# 1335   18  female  36.850          0     no   1629.83350
# 1336   21  female  25.800          0     no   2007.94500
# 1337   61  female  29.070          0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
df.describe()
# Out:
#                age          bmi    dependent       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        1338 non-null   int64
#  1   Gender     1338 non-null   object
#  2   bmi        1338 non-null   float64
#  3   dependent  1338 non-null   int64
#  4   smoker     1338 non-null   object
#  5   charges    1338 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 62.8+ KB

# %%
#this just check if there is null value inside our dataframe!
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <AxesSubplot: >

# %%
age_unique = df['age'].unique()

# %%
age_unique_counts = df["age"].value_counts()

# %%
age_unique_counts
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
#I created 2 graphs please choose which method you think is better: 

# plt.xlabel('Count of Population Based on Age')
# plt.ylabel('Count of People')
# plt.title('Age')
#plt.xlim(-10,100)  # adjust as necessary
#plt.xticks( color='orange', rotation=90, fontweight='bold', fontsize='8', horizontalalignment='right')
plt.figure(figsize=(20, 3))  # width:20, height:3
#plt.bar(range(len(my_dict)), my_dict.values(), align='edge', width=0.3)
age_unique_counts.plot.bar(x='age', y='Number of People', rot=0)
# Out:
# <AxesSubplot: >

# %%
# this is the second method to create he same graph above

# creating the dataset 
ages = list(age_unique_counts.keys()) 
values = [age_unique_counts[keys] for keys in age_unique_counts.keys() ]
   

fig = plt.figure(figsize = (20, 10)) 
  
# creating the bar plot 
plt.bar(ages, values, color ='green',  
        width = 0.6) 
  
plt.xlabel("Ages") 
plt.ylabel("Count of People") 
plt.title("Count of People Classified by Ages") 
plt.show()

# %%
df['Gender']
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: Gender, Length: 1338, dtype: object

# %%
df["Gender"]
gender_unique_value = df["Gender"].value_counts()
df["smoker"]
smoker_unique_value = df["smoker"].value_counts()

# %%
#directly creating pie chart from the dataframe
gender_pie_chart = gender_unique_value.plot.pie(y='mass', figsize=(5, 5))

# %%
#directly creating pie chart from the dataframe
smoker_pie_chart = smoker_unique_value.plot.pie(y='mass', figsize=(5, 5))

# %%
# another implementation
# Dataset
labels = gender_unique_value.keys()
sizes = [gender_unique_value[keys] for keys in labels]
# Plot
plt.pie(sizes, labels=labels, 
        autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.show()

# %%
# another implementation
# Dataset
labels = smoker_unique_value.keys()
sizes = [smoker_unique_value[keys] for keys in labels]
# Plot
plt.pie(sizes, labels=labels, 
        autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.show()

# %%
# Out:
# [69,
#  68,
#  29,
#  29,
#  29,
#  29,
#  29,
#  29,
#  29,
#  29,
#  28,
#  28,
#  28,
#  28,
#  28,
#  28,
#  28,
#  28,
#  28,
#  28,
#  28,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  26,
#  26,
#  26,
#  26,
#  26,
#  26,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  23,
#  23,
#  23,
#  23,
#  22]

# %%
# Make Bloxplot to see the normality for ages
age = df["age"]
age_boxplot = age.plot(kind = 'box')

# %%
# Make histogram to see if normal or not
age.hist()
# Out:
# <AxesSubplot: >

# %%
bmi = df["bmi"]
bmi.plot(kind = 'box')
# Out:
# <AxesSubplot: >

# %%
# Seems there is an outlier because it is outside the max and min which is the dots outside the whisker
def outlier(col:str, df_:pd.DataFrame=df, remove:bool=False) -> list:
    """This function calculates the upper and lower fence
    of any column and can also remove from the dataset"""
    q1 = df_[col].quantile(0.25)
    q3 = df_[col].quantile(0.75)
    
    iqr = q3-q1
    lower_fence = q1 - iqr*1.5
    upper_fence = q3 + iqr*1.5

    if remove:
        temp = df_[(df_[col] > lower_fence) & (df_[col] < upper_fence)]
        return temp

    return [lower_fence, upper_fence]

# %%
bmi_outlier = outlier(df_= df, col="bmi")

# %%
bmi_outlier
# Out:
# [13.7, 47.290000000000006]

# %%
bmi.hist()
# Out:
# <AxesSubplot: >

# %%
dependent = df["dependent"]
dependent.plot(kind = 'box')
# Out:
# <AxesSubplot: >

# %%
dependent.hist()
# Out:
# <AxesSubplot: >

# %%
charges = df["charges"]
charges.plot(kind = 'box')
# Out:
# <AxesSubplot: >

# %%
charges.hist()
# Out:
# <AxesSubplot: >

# %%
charges_outlier = outlier(df_= df, col="charges")

# %%
charges_outlier
# Out:
# [-13109.1508975, 34489.350562499996]

# %%
# Finding hte correlation between variables
#load the dataset
#df = sns.load_dataset('iris')
#calculate correlation
corr_matrix = df.corr('pearson') #kind of correlation->  ‘pearson’, ‘kendall’, ‘spearman’
#plot correlation
corr_matrix.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# C:\Users\dsitepu\AppData\Local\Temp\1\ipykernel_5864\3405528436.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr('pearson') #kind of correlation->  ‘pearson’, ‘kendall’, ‘spearman’
# <style type="text/css">
# #T_a13f3_row0_col0, #T_a13f3_row1_col1, #T_a13f3_row2_col2, #T_a13f3_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a13f3_row0_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_a13f3_row0_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a13f3_row0_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a13f3_row1_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a13f3_row1_col2, #T_a13f3_row2_col0, #T_a13f3_row2_col1, #T_a13f3_row2_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# ...

# %%
df_drop = df.drop(['dependent'], axis = 1)

# %%
df_drop
# Out:
#       age  Gender     bmi smoker      charges
# 0      19  female  27.900    yes  16884.92400
# 1      18    male  33.770     no   1725.55230
# 2      28    male  33.000     no   4449.46200
# 3      33    male  22.705     no  21984.47061
# 4      32    male  28.880     no   3866.85520
# ...   ...     ...     ...    ...          ...
# 1333   50    male  30.970     no  10600.54830
# 1334   18  female  31.920     no   2205.98080
# 1335   18  female  36.850     no   1629.83350
# 1336   21  female  25.800     no   2007.94500
# 1337   61  female  29.070    yes  29141.36030
#
# [1338 rows x 5 columns]

# %%
#activate the onehotencoder
encoder = ce.OneHotEncoder()
encoder.fit_transform(df_drop).head()
# Out:
# C:\Users\dsitepu\Anaconda3\envs\cds_assigment2\lib\site-packages\category_encoders\one_hot.py:145: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for cat_name, class_ in values.iteritems():
# C:\Users\dsitepu\Anaconda3\envs\cds_assigment2\lib\site-packages\category_encoders\one_hot.py:145: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for cat_name, class_ in values.iteritems():
#    age  Gender_1  Gender_2     bmi  smoker_1  smoker_2      charges
# 0   19         1         0  27.900         1         0  16884.92400
# 1   18         0         1  33.770         0         1   1725.55230
# 2   28         0         1  33.000         0         1   4449.46200
# 3   33         0         1  22.705         0         1  21984.47061
# 4   32         0         1  28.880         0         1   3866.85520

# %%
#encode the data using the category_encoders 
df_encoded = encoder.fit_transform(df_drop)
# Out:
# C:\Users\dsitepu\Anaconda3\envs\cds_assigment2\lib\site-packages\category_encoders\one_hot.py:145: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for cat_name, class_ in values.iteritems():
# C:\Users\dsitepu\Anaconda3\envs\cds_assigment2\lib\site-packages\category_encoders\one_hot.py:145: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for cat_name, class_ in values.iteritems():

# %%
df_encoded
# Out:
#       age  Gender_1  Gender_2     bmi  smoker_1  smoker_2      charges
# 0      19         1         0  27.900         1         0  16884.92400
# 1      18         0         1  33.770         0         1   1725.55230
# 2      28         0         1  33.000         0         1   4449.46200
# 3      33         0         1  22.705         0         1  21984.47061
# 4      32         0         1  28.880         0         1   3866.85520
# ...   ...       ...       ...     ...       ...       ...          ...
# 1333   50         0         1  30.970         0         1  10600.54830
# 1334   18         1         0  31.920         0         1   2205.98080
# 1335   18         1         0  36.850         0         1   1629.83350
# 1336   21         1         0  25.800         0         1   2007.94500
# 1337   61         1         0  29.070         1         0  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_encoded_renamed = df_encoded.rename(columns = {'Gender_1':'female', 'Gender_2':'male', 'smoker_1':'smoker_yes', 'smoker_2':'smoker_no'})

# %%
df_encoded_renamed
# Out:
#       age  female  male     bmi  smoker_yes  smoker_no      charges
# 0      19       1     0  27.900           1          0  16884.92400
# 1      18       0     1  33.770           0          1   1725.55230
# 2      28       0     1  33.000           0          1   4449.46200
# 3      33       0     1  22.705           0          1  21984.47061
# 4      32       0     1  28.880           0          1   3866.85520
# ...   ...     ...   ...     ...         ...        ...          ...
# 1333   50       0     1  30.970           0          1  10600.54830
# 1334   18       1     0  31.920           0          1   2205.98080
# 1335   18       1     0  36.850           0          1   1629.83350
# 1336   21       1     0  25.800           0          1   2007.94500
# 1337   61       1     0  29.070           1          0  29141.36030
#
# [1338 rows x 7 columns]

# %%
#calculate correlation
corr_matrix = df_encoded_renamed.corr('pearson') #kind of correlation->  ‘pearson’, ‘kendall’, ‘spearman’
#plot correlation
corr_matrix.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style type="text/css">
# #T_216d2_row0_col0, #T_216d2_row1_col1, #T_216d2_row2_col2, #T_216d2_row3_col3, #T_216d2_row4_col4, #T_216d2_row5_col5, #T_216d2_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_216d2_row0_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_216d2_row0_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_216d2_row0_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_216d2_row0_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_216d2_row0_col5 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_216d2_row0_col6 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_216d2_row1_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_216d2_row1_col2, #T_216d2_row1_col3, #T_216d2_row2_col1, #T_216d2_row4_col0, #T_216d2_row4_col5, #T_216d2_row5_col4, #T_216d2_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.model_selection import train_test_split
X = df_encoded_renamed.drop(['charges'],axis=1).values
y = df_encoded_renamed['charges'].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
X_test
# Out:
# array([[45.  ,  0.  ,  1.  , 24.31,  0.  ,  1.  ],
#        [54.  ,  0.  ,  1.  , 21.01,  0.  ,  1.  ],
#        [44.  ,  1.  ,  0.  , 25.  ,  0.  ,  1.  ],
#        ...,
#        [58.  ,  1.  ,  0.  , 36.48,  0.  ,  1.  ],
#        [59.  ,  0.  ,  1.  , 25.46,  0.  ,  1.  ],
#        [18.  ,  1.  ,  0.  , 31.35,  0.  ,  1.  ]])

# %%
from sklearn.linear_model import LinearRegression
X_train.shape
# Out:
# (1003, 6)

# %%
y_train.shape
# Out:
# (1003,)

# %%
 X_train_reshape = X_train.reshape((-1, 1))

# %%
X_train_reshape
# Out:
# array([[59. ],
#        [ 1. ],
#        [ 0. ],
#        ...,
#        [34.9],
#        [ 1. ],
#        [ 0. ]])

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
r_sq = model.score(X_train, y_train)
print(f"coefficient of determination: {r_sq}")
# Out:
# coefficient of determination: 0.7493193082801108

# %%
print(f"intercept: {model.intercept_}")

print(f"slope: {model.coef_}")
# Out:
# intercept: -77.67581374559086
# slope: [   273.45039168    -97.34949042     97.34949042    315.47906368
#   11905.61849697 -11905.61849697]
